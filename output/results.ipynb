# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Speedup (S) = T_seq / T_par

# %% [markdown]
# ## Parallel Efficiency (E) = S/P    (p -> No. of threads)

# %%
s_values = [
    0.298748, 0.215434, 0.0852617, 0.0911017, 0.219882,
    0.0972214, 0.0318433, 0.0572883, 0.24632, 0.0196978,
    0.0969495, 0.0595427, 0.118972, 0.0426423, 0.17621,
    0.129506, 0.0730005, 0.0767271, 0.0286972, 0.0632194,
    0.00576736, 0.0229303, 0.0607918, 0.0511223, 0.152185,
    0.139195, 0.0460433, 0.0973409, 0.0332155, 0.10048,
    0.115254, 0.0925542, 0.0617595, 0.0243857, 0.130946,
    0.0289932, 0.0294074, 0.100163, 0.105528, 0.11527,
    0.0808565, 0.0754669, 0.059945, 0.0300461, 0.134315,
    0.0640461, 0.0269982, 0.0512379, 0.143241, 0.0317849
]

p_values = [
    0.0508026, 0.0384928, 0.0375536, 0.0378702, 0.0170531,
    0.0124769, 0.0103804, 0.00900867, 0.00797892, 0.00776686,
    0.00796172, 0.00776878, 0.00763993, 0.00767597, 0.00821689,
    0.00772838, 0.00764176, 0.00834912, 0.00922951, 0.00867532,
    0.00687218, 0.00606261, 0.0064766, 0.00597806, 0.00647475,
    0.00652518, 0.00612174, 0.00668933, 0.00579058, 0.00599302,
    0.00657859, 0.00583624, 0.00647626, 0.00646333, 0.00760557,
    0.00677095, 0.0058572, 0.00652861, 0.00680778, 0.00601974,
    0.00683812, 0.00653734, 0.00636726, 0.0070758, 0.00614864,
    0.00695471, 0.00690728, 0.00614125, 0.0065813, 0.00796127
]


fig, ax = plt.subplots()


ax.plot(range(1, len(s_values) + 1),s_values, label='Serialized iter time')

# Plot the second list
ax.plot(range(1, len(p_values) + 1),p_values, label='Parallelised iter time')

# Set labels and title
ax.set_xlabel('Iteration Number')
ax.set_ylabel('Time (seconds)')
ax.set_title('Time vs Iteration Number')

# Show legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# # 4 threads

# %%
values = [
    0.0421725, 0.0533708, 0.051511, 0.0384466, 0.0403588,
    0.038, 0.0229162, 0.0132513, 0.0142535, 0.0125285,
    0.0112608, 0.0112842, 0.0119571, 0.0124651, 0.0124453,
    0.00933146, 0.0108782, 0.00864595, 0.00837103, 0.00829099,
    0.0077431, 0.00746205, 0.00971923, 0.00792731, 0.00837935,
    0.00842574, 0.00802047, 0.00860812, 0.00845907, 0.00800674,
    0.00844507, 0.00897435, 0.00843146, 0.0088166, 0.00974897,
    0.00830666, 0.00872251, 0.0107288, 0.0112198, 0.0116605,
    0.00973685, 0.0111715, 0.0103774, 0.0101138, 0.00806793,
    0.00810253, 0.00828806, 0.00815079, 0.00846251, 0.00980033
]
iterations = list(range(1, 51))
plt.plot(iterations, values, marker='o', linestyle='-')
plt.title('SpeedUp for 4 processing elements')
plt.xlabel('Iteration Number')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.show()

# %% [markdown]
# # 8 threads

# %%
values = [
    0.0508026, 0.0384928, 0.0375536, 0.0378702, 0.0170531,
    0.0124769, 0.0103804, 0.00900867, 0.00797892, 0.00776686,
    0.00796172, 0.00776878, 0.00763993, 0.00767597, 0.00821689,
    0.00772838, 0.00764176, 0.00834912, 0.00922951, 0.00867532,
    0.00687218, 0.00606261, 0.0064766, 0.00597806, 0.00647475,
    0.00652518, 0.00612174, 0.00668933, 0.00579058, 0.00599302,
    0.00657859, 0.00583624, 0.00647626, 0.00646333, 0.00760557,
    0.00677095, 0.0058572, 0.00652861, 0.00680778, 0.00601974,
    0.00683812, 0.00653734, 0.00636726, 0.0070758, 0.00614864,
    0.00695471, 0.00690728, 0.00614125, 0.0065813, 0.00796127
]

iterations = list(range(1, 51))
plt.plot(iterations, values, marker='o', linestyle='-')
plt.title('SpeedUp for 8 processing elements')
plt.xlabel('Iteration Number')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.show()
